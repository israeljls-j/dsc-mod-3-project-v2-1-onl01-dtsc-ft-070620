# %% [markdown]
# ### <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Final-Project-Submission" data-toc-modified-id="1.-Final-Project-Submission-1">1. Final Project Submission</a></span></li><li><span><a href="#Business-Understanding" data-toc-modified-id="Business-Understanding-2">Business Understanding</a></span></li><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-3">Problem Statement</a></span></li><li><span><a href="#2.-Objective" data-toc-modified-id="2.-Objective-4">2. Objective</a></span></li><li><span><a href="#3.-Mission" data-toc-modified-id="3.-Mission-5">3. Mission</a></span></li><li><span><a href="#4.-EDAs" data-toc-modified-id="4.-EDAs-6">4. EDAs</a></span></li><li><span><a href="#5.-Import-Packages" data-toc-modified-id="5.-Import-Packages-7">5. Import Packages</a></span></li><li><span><a href="#6.-Transform-the-Data" data-toc-modified-id="6.-Transform-the-Data-8">6. Transform the Data</a></span></li><li><span><a href="#7.--Data-Cleaning" data-toc-modified-id="7.--Data-Cleaning-9">7.  Data Cleaning</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Review-column-names-and-rename-as-needed" data-toc-modified-id="Review-column-names-and-rename-as-needed-9.0.1">Review column names and rename as needed</a></span></li><li><span><a href="#Check-for-duplicates" data-toc-modified-id="Check-for-duplicates-9.0.2">Check for duplicates</a></span></li><li><span><a href="#Null-Values" data-toc-modified-id="Null-Values-9.0.3">Null Values</a></span></li><li><span><a href="#Check-value_counts" data-toc-modified-id="Check-value_counts-9.0.4">Check value_counts</a></span></li></ul></li></ul></li><li><span><a href="#8.-Exploration" data-toc-modified-id="8.-Exploration-10">8. Exploration</a></span></li><li><span><a href="#9.-Multicolinearity" data-toc-modified-id="9.-Multicolinearity-11">9. Multicolinearity</a></span><ul class="toc-item"><li><span><a href="#10.-Initial-Feature-Engineering" data-toc-modified-id="10.-Initial-Feature-Engineering-11.1">10. Initial Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Numeric-Data" data-toc-modified-id="Numeric-Data-11.1.1">Numeric Data</a></span></li><li><span><a href="#Categorical-Data" data-toc-modified-id="Categorical-Data-11.1.2">Categorical Data</a></span></li></ul></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-11.2">Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Train-,-test,-split" data-toc-modified-id="Train-,-test,-split-11.2.1">Train , test, split</a></span></li><li><span><a href="#One-Hot-Encoding" data-toc-modified-id="One-Hot-Encoding-11.2.2">One Hot Encoding</a></span></li><li><span><a href="#Label-Binarizer" data-toc-modified-id="Label-Binarizer-11.2.3">Label Binarizer</a></span></li><li><span><a href="#Scale-data" data-toc-modified-id="Scale-data-11.2.4">Scale data</a></span></li></ul></li><li><span><a href="#Logistic-Regression---Model-1.v1---statsmodel" data-toc-modified-id="Logistic-Regression---Model-1.v1---statsmodel-11.3">Logistic Regression - Model 1.v1 - statsmodel</a></span></li><li><span><a href="#Logistic-Regression---Model-1.v2---statsmodel" data-toc-modified-id="Logistic-Regression---Model-1.v2---statsmodel-11.4">Logistic Regression - Model 1.v2 - statsmodel</a></span></li><li><span><a href="#Logistic-Regression---Model-1.v1---sklearn" data-toc-modified-id="Logistic-Regression---Model-1.v1---sklearn-11.5">Logistic Regression - Model 1.v1 - sklearn</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression---Model-2---sklearn2" data-toc-modified-id="Logistic-Regression---Model-2---sklearn2-11.5.1">Logistic Regression - Model 2 - sklearn2</a></span></li></ul></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-11.6">Random Forest</a></span></li><li><span><a href="#XG-Boost" data-toc-modified-id="XG-Boost-11.7">XG Boost</a></span></li></ul></li><li><span><a href="#19.-Cross---Validation" data-toc-modified-id="19.-Cross---Validation-12">19. Cross - Validation</a></span></li><li><span><a href="#20.-Conclusion" data-toc-modified-id="20.-Conclusion-13">20. Conclusion</a></span><ul class="toc-item"><li><span><a href="#The-Data" data-toc-modified-id="The-Data-13.1">The Data</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-13.2">Conclusion</a></span></li></ul></li></ul></div>

# %% [markdown]
# # 1. Final Project Submission
#
# Please fill out:
# * Student name: Joan Leonard Short
# * Student pace: self paced / part time / full time: full-time
# * Scheduled project review date/time:
# * Instructor name: James Irving
# * Blog post URL:

# %% [markdown]
# # Business Understanding

# %% [markdown]
# #### 'Churn' is a major cost to the telecom industry and is defined as customer disengagement from a vendor to move to another vendor.  Most of the costs relate to the initial discounts given to a customer and the initial cost setting up a customer.
# #### There are many factors involved in why a customer leaves: cost, slow to no resolutions to problems etc. but the primary reason is a bad experience with the company: outages, bad customer service experience, non-returned calls and feeling that they don't matter to the company.
# #### Reasons for leaving are noted below:
#   - Customer Service - 70%       - Quality - 30%
#   - Price - 24%
#   - Functionality - 13%
#   - Other 30%
#
# #### 82% of companies claim that retention is cheaper than acquisition and a 2% increase in retention could reduce costs by 10%.
#
# #### The average churn rate for the industry is 10% to 60%

# %% [markdown]
# # Problem Statement

# %% [markdown]
# #### Churn at SyriaTel is currently 14.5%.  Churn adds significant costs to the client because of the initial discounts given and the high cost of adding a customer

# %% [markdown]
# # 2. Objective

# %% [markdown]
# ### <span style='font-family:Helvetica'>
# ###### Using the data provided by the client(SyriaTel), the objective is to predict the customers who will become 'churn',  meaning that they will disengage with the client and move to another vendor.

# %% [markdown]
# <h1>3. Mission</h1>

# %% [markdown]
# ##### Our mission is to obtain, understand and analyze the dataset provided by the client and to use analytical, graphical and statistical means to predict customer churn. This analysis is considered binary classification because the prediction will be binary - churn/no churn and our goal is for inference of the predictions .

# %% [markdown]
# # 4. EDAs#

# %% [markdown]
# 1. What metrics will show success with this project?
#       1. recall, ROC
#       2. balance
#       3. features
#           a. p-value of features
#           b. correlation of features - numeric?

# %% [markdown]
# 2. What features seem most important?

# %% [markdown]
# 3. Which models work best?
#       a. logistic regression
#       b. random forest
#       c. gradient boosting
#       d. lasso for features/regularization
#       e. balancing

# %% [markdown]
# 4. What would I do differently?

# %% [markdown]
# <h1>5. Import Packages</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# import six
# import sys
# sys.modules['sklearn.externals.six'] = six
# from imblearn.over_sampling import SMOTE, ADASYN

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# <h1>6. Transform the Data</h1>

# %%
# read-in data and create dataset df
df = pd.read_csv('bigml_59c28831336c6604c800002a.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
# DataFrame with 21 columns of telecom and 3,333 rows with no blank missing data, with 4 objects, 8 int64, 8 float and 1 boolean
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
df.shape
# Out:
# (3333, 21)

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# #### State, telephone number, international plan and vmail plans are all missing because they are objects.
# #### Analysis of data will be to see if any of the number columns are candidates for classifiaction

# %% [markdown]
# # 7.  Data Cleaning #

# %% [markdown]
# * ### Review column names and rename as needed

# %%
# column names - change date to date_sold, view to viewed_by_buyer
#df.columns

df.rename(columns={'account length' : 'acct_len', 'area code' : 'area_code', 'phone number' : 'phone_num',
       'international plan' : 'intl_plan', 'voice mail plan': 'vmail_plan', 'number vmail messages' : 'num_vmail_messages',
       'total day minutes' : 'day_min', 'total day calls' : 'day_calls', 'total day charge' : 'day_charge',
       'total eve minutes' : 'eve_min', 'total eve calls' : 'eve_calls', 'total eve charge' : 'eve_charge',
       'total night minutes' : 'night_min', 'total night calls' : 'night_calls', 'total night charge' : 'night_charge',
       'total intl minutes' : 'intl_min', 'total intl calls' : 'intl_calls', 'total intl charge' : 'intl_charge',
       'customer service calls' : 'cs_calls'}, inplace=True)

# %% [markdown]
# * ### Check for duplicates ###

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, acct_len, area_code, phone_num, intl_plan, vmail_plan, num_vmail_messages, day_min, day_calls, day_charge, eve_min, eve_calls, eve_charge, night_min, night_calls, night_charge, intl_min, intl_calls, intl_charge, cs_calls, churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# * ### Null Values

# %%
#NAs
df_null = {}
for item in df.columns:
    df_null[item] = df[item].isnull().sum().sum()
df_null
# Out:
# {'state': 0,
#  'acct_len': 0,
#  'area_code': 0,
#  'phone_num': 0,
#  'intl_plan': 0,
#  'vmail_plan': 0,
#  'num_vmail_messages': 0,
#  'day_min': 0,
#  'day_calls': 0,
#  'day_charge': 0,
#  'eve_min': 0,
#  'eve_calls': 0,
#  'eve_charge': 0,
#  'night_min': 0,
#  'night_calls': 0,
#  'night_charge': 0,
#  'intl_min': 0,
#  'intl_calls': 0,
#  'intl_charge': 0,
#  'cs_calls': 0,
#  'churn': 0}

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               3333 non-null   object
#  1   acct_len            3333 non-null   int64
#  2   area_code           3333 non-null   int64
#  3   phone_num           3333 non-null   object
#  4   intl_plan           3333 non-null   object
#  5   vmail_plan          3333 non-null   object
#  6   num_vmail_messages  3333 non-null   int64
#  7   day_min             3333 non-null   float64
#  8   day_calls           3333 non-null   int64
#  9   day_charge          3333 non-null   float64
#  10  eve_min             3333 non-null   float64
#  11  eve_calls           3333 non-null   int64
#  12  eve_charge          3333 non-null   float64
#  13  night_min           3333 non-null   float64
#  14  night_calls         3333 non-null   int64
# ...

# %%
objects = ['state', 'phone_num', 'intl_plan', 'vmail_plan']
ints = ['acct_len', 'area_code', 'num_vmail_messages', 'day_calls', 'eve_calls', 'night_calls', 'intl_calls', 'cs_calls']
floats = ['day_min', 'day_charge', 'eve_min', 'eve_charge', 'night_min', 'night_charge', 'intl_min', 'intl_charge' ]
bools = ['churn']

# %%
for col in floats:
    for item in df.columns:
        if item  == col:
            df[item] = df[item].astype('int')
        
ints = ints + floats  
ints
# Out:
# ['acct_len',
#  'area_code',
#  'num_vmail_messages',
#  'day_calls',
#  'eve_calls',
#  'night_calls',
#  'intl_calls',
#  'cs_calls',
#  'day_min',
#  'day_charge',
#  'eve_min',
#  'eve_charge',
#  'night_min',
#  'night_charge',
#  'intl_min',
#  'intl_charge']

# %%
df['target'] = df['churn'].astype('int')

# %%
df['target'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: target, dtype: int64

# %% [markdown]
# ### Check value_counts

# %%
pd.set_option('display.max_rows', 1000)

# %%
for item in ints:
    display(item, df[item].value_counts(dropna = False))
# Out:
# 'acct_len'
# 105    43
# 87     42
# 93     40
# 101    40
# 90     39
# 86     38
# 95     38
# 116    37
# 100    37
# 112    36
# 107    36
# 99     36
# 120    35
# 127    35
# 123    35
# 106    34
# 122    34
# 88     34
# 103    33
# 80     33
# 92     33
# 94     33
# 98     32
# 74     32
# 119    32
# 117    32
# 73     32
# 75     32
# 64     32
# 113    32
# 121    31
# 78     31
# 115    31
# 130    30
# 108    30
# 68     30
# 85     30
# 110    29
# 111    29
# 97     29
# 104    28
# 91     28
# 124    28
# 125    28
# 84     27
# 67     27
# 63     27
# 132    27
# 129    26
# 96     26
# 148    26
# 89     26
# 70     26
# 137    25
# 136    25
# 81     25
# 138    25
# 72     25
# 82     25
# 131    25
# 109    24
# 76     24
# 118    24
# 83     24
# 102    23
# 114    23
# 79     23
# 128    22
# 141    22
# 77     22
# 149    21
# 126    21
# 65     21
# 66     21
# 134    21
# 62     20
# 71     19
# 139    19
# 57     19
# 55     19
# 146    18
# 135    18
# ...

# %% [markdown]
# The following analysis is to see if we have continuous data that could be categorized:

# %%
df.hist('acct_len', bins=6)
# Out:
# array([[<AxesSubplot:title={'center':'acct_len'}>]], dtype=object)

# %%
print(df['acct_len'].describe())
# Out:
# count    3333.000000
# mean      101.064806
# std        39.822106
# min         1.000000
# 25%        74.000000
# 50%       101.000000
# 75%       127.000000
# max       243.000000
# Name: acct_len, dtype: float64

# %%
df['target'].value_counts(1) #unbalanced target value
# Out:
# 0    0.855086
# 1    0.144914
# Name: target, dtype: float64

# %%
df['acct_len'].value_counts(sort=True, ascending=False, bins=6) # do not categorize
# Out:
# (81.667, 122.0]       1313
# (41.333, 81.667]       813
# (122.0, 162.333]       762
# (0.757, 41.333]        234
# (162.333, 202.667]     189
# (202.667, 243.0]        22
# Name: acct_len, dtype: int64

# %%
df['area_code'].value_counts() #categorize
# Out:
# 415    1655
# 510     840
# 408     838
# Name: area_code, dtype: int64

# %%
loc_area_code_grp = df.groupby(['area_code']).mean()
loc_area_code_grp
# Out:
#              acct_len  num_vmail_messages     day_min   day_calls  day_charge  \
# area_code
# 408        101.877088            7.668258  176.726730  100.496420   29.627685
# 415        101.068882            8.357704  181.143807  100.576435   30.371601
# 510        100.246429            8.019048  178.341667  100.097619   29.910714
#
#               eve_min   eve_calls  eve_charge   night_min  night_calls  \
# area_code
# 408        200.824582   99.788783   16.622912  198.782816    99.039379
# 415        200.199396  100.503927   16.546224  201.577644   100.398187
# 510        200.870238   99.671429   16.625000  199.782143   100.601190
#
#            night_charge  intl_min  intl_calls  intl_charge  cs_calls  \
# area_code
# 408            8.484487  9.688544    4.426014     2.258950  1.519093
# 415            8.592749  9.899094    4.561934     2.309970  1.554079
# 510            8.497619  9.689286    4.370238     2.254762  1.623810
#
#               churn    target
# area_code
# ...

# %% [markdown]
# #### Remove unnecessary column - telephone number

# %%
df.drop(['phone_num'], axis=1, inplace=True)
objects.remove('phone_num')

# %%
print(objects, floats, ints, bool)
# Out:
# ['state', 'intl_plan', 'vmail_plan'] ['day_min', 'day_charge', 'eve_min', 'eve_charge', 'night_min', 'night_charge', 'intl_min', 'intl_charge'] ['acct_len', 'area_code', 'num_vmail_messages', 'day_calls', 'eve_calls', 'night_calls', 'intl_calls', 'cs_calls', 'day_min', 'day_charge', 'eve_min', 'eve_charge', 'night_min', 'night_charge', 'intl_min', 'intl_charge'] <class 'bool'>

# %% [markdown]
# # 8. Exploration#

# %%
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = [4,4]

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['state', 'acct_len', 'area_code', 'intl_plan', 'vmail_plan',
#        'num_vmail_messages', 'day_min', 'day_calls', 'day_charge', 'eve_min',
#        'eve_calls', 'eve_charge', 'night_min', 'night_calls', 'night_charge',
#        'intl_min', 'intl_calls', 'intl_charge', 'cs_calls', 'churn', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#   state  acct_len  area_code intl_plan vmail_plan  num_vmail_messages  \
# 0    KS       128        415        no        yes                  25
# 1    OH       107        415        no        yes                  26
# 2    NJ       137        415        no         no                   0
# 3    OH        84        408       yes         no                   0
# 4    OK        75        415       yes         no                   0
#
#    day_min  day_calls  day_charge  eve_min  ...  eve_charge  night_min  \
# 0      265        110          45      197  ...          16        244
# 1      161        123          27      195  ...          16        254
# 2      243        114          41      121  ...          10        162
# 3      299         71          50       61  ...           5        196
# 4      166        113          28      148  ...          12        186
#
#    night_calls  night_charge  intl_min  intl_calls  intl_charge  cs_calls  \
# ...

# %%
df.describe()
# Out:
#           acct_len    area_code  num_vmail_messages      day_min    day_calls  \
# count  3333.000000  3333.000000         3333.000000  3333.000000  3333.000000
# mean    101.064806   437.182418            8.099010   179.327033   100.435644
# std      39.822106    42.371290           13.688365    54.466036    20.069084
# min       1.000000   408.000000            0.000000     0.000000     0.000000
# 25%      74.000000   408.000000            0.000000   143.000000    87.000000
# 50%     101.000000   415.000000            0.000000   179.000000   101.000000
# 75%     127.000000   510.000000           20.000000   216.000000   114.000000
# max     243.000000   510.000000           51.000000   350.000000   165.000000
#
#         day_charge      eve_min    eve_calls   eve_charge    night_min  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.068407   200.525653   100.114311    16.585359   200.422442
# ...

# %%
df['num_vmail_messages'].value_counts()
# Out:
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# 25      37
# 23      36
# 36      34
# 35      32
# 22      32
# 39      30
# 37      29
# 34      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 41      13
# 16      13
# 43       9
# 15       9
# 18       7
# 44       7
# 14       7
# 45       6
# 12       6
# 46       4
# 13       4
# 47       3
# 8        2
# 48       2
# 50       2
# 9        2
# 11       2
# 49       1
# 10       1
# 4        1
# 51       1
# Name: num_vmail_messages, dtype: int64

# %%
df['num_vmail_messages'].median()
# Out:
# 0.0

# %%
df['num_vmail_messages'].value_counts(normalize=True)
# Out:
# 0     0.723372
# 31    0.018002
# 29    0.015902
# 28    0.015302
# 33    0.013801
# 27    0.013201
# 30    0.013201
# 24    0.012601
# 26    0.012301
# 32    0.012301
# 25    0.011101
# 23    0.010801
# 36    0.010201
# 35    0.009601
# 22    0.009601
# 39    0.009001
# 37    0.008701
# 34    0.008701
# 21    0.008401
# 38    0.007501
# 20    0.006601
# 19    0.005701
# 40    0.004800
# 42    0.004500
# 17    0.004200
# 41    0.003900
# 16    0.003900
# 43    0.002700
# 15    0.002700
# 18    0.002100
# 44    0.002100
# 14    0.002100
# 45    0.001800
# 12    0.001800
# 46    0.001200
# 13    0.001200
# 47    0.000900
# 8     0.000600
# 48    0.000600
# 50    0.000600
# 9     0.000600
# 11    0.000600
# 49    0.000300
# 10    0.000300
# 4     0.000300
# 51    0.000300
# Name: num_vmail_messages, dtype: float64

# %% [markdown]
# 72% of values = 0 which is driving the strange numbers in .describe().  Seems reasonable that there would be many customers without vmail service.

# %% [markdown]
# Calculate current churn

# %%
df.shape
df['target'] = df['churn'].astype('int')
target = df['target']
orig_churn = round(df['churn'].sum() / df['target'].count(),3)
orig_churn
# Out:
# 0.145

# %%
target.value_counts()
current_churn = round(target.sum() / len(target),3)
current_churn
# Out:
# 0.145

# %%
df.drop('churn', axis=1, inplace=True)
df.head()
# Out:
#   state  acct_len  area_code intl_plan vmail_plan  num_vmail_messages  \
# 0    KS       128        415        no        yes                  25
# 1    OH       107        415        no        yes                  26
# 2    NJ       137        415        no         no                   0
# 3    OH        84        408       yes         no                   0
# 4    OK        75        415       yes         no                   0
#
#    day_min  day_calls  day_charge  eve_min  eve_calls  eve_charge  night_min  \
# 0      265        110          45      197         99          16        244
# 1      161        123          27      195        103          16        254
# 2      243        114          41      121        110          10        162
# 3      299         71          50       61         88           5        196
# 4      166        113          28      148        122          12        186
#
#    night_calls  night_charge  intl_min  intl_calls  intl_charge  cs_calls  \
# ...

# %%
fig,a =  plt.subplots(ncols=3,nrows=6, figsize=(10, 10))
x = np.arange(1,12)
a[0][0].hist(df['acct_len'], color = 'g')
a[0][0].set_title('acct_len', color = 'g')
a[0][1].hist(df['area_code'], color = 'g')
a[0][1].set_title('area_code', color = 'g')
a[0][2].hist(df['num_vmail_messages'], color = 'g')
a[0][2].set_title('num_vmail_messages', color = 'g')
a[1][0].hist(df['day_min'], color = 'blue')
a[1][0].set_title('day_min', color='blue')
a[1][1].hist(df['day_calls'], color= 'k')
a[1][1].set_title('day_calls', color = 'k')
a[1][2].hist(df['day_charge'], color = 'red')
a[1][2].set_title('day_charge', color = 'red')
a[2][0].hist(df['eve_min'], color='blue')
a[2][0].set_title('eve_min', color = 'blue')
a[2][1].hist(df['eve_calls'], color = 'k')
a[2][1].set_title('eve_calls', color = 'k')
a[2][2].hist(df['eve_charge'], color = 'red')
a[2][2].set_title('eve_charge', color = 'red')
a[3][0].hist(df['night_min'], color = 'blue')
a[3][0].set_title('night_min', color = 'blue')
a[3][1].hist(df['night_calls'], color='k')
a[3][1].set_title('night_calls', color = 'k')
a[3][2].hist(df['night_charge'], color= 'red')
a[3][2].set_title('night_charge', color = 'red')
a[4][0].hist(df['intl_min'], color='blue')
a[4][0].set_title('intl_min', color='blue')
a[4][1].hist(df['intl_calls'],color = 'k')
a[4][1].set_title('intl_calls', color = 'k')
a[4][2].hist(df['intl_charge'], color = 'red')
a[4][2].set_title('intl_charge', color = 'red')
a[5][0].hist(df['cs_calls'], color = 'g')
a[5][0].set_title('cs_charge', color = 'g')
a[5][1].hist(df['target'], color = 'g')
a[5][1].set_title('target', color = 'g')
plt.tight_layout()
plt.show()

# %%
from scipy import stats
def normal_Xy(df, columns):
    for col in columns:
        for colum in ints:
            if colum == col:
                X = df[col]
                fig, ax = plt.subplots(figsize=(5,3))                         
                sns.distplot(X, ax=ax, kde=False, bins = 'auto')
                ax.set(xlabel= col)
                stat, p =  stats.normaltest(X)
                ax.set_title(f"{col} Normality: {round(p, 3)}" )
                print(fig, ax)
                plt.show()
normal_Xy(df, df.columns)
# Out:
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)
# Figure(360x216) AxesSubplot(0.08,0.07;0.87x0.81)

# %% [markdown]
# Columns that are closer to normal:
#  - day_min = .769
#  - day_chg = .788
#  - eve_min = .810
#  - eve_charge .767
#  - night_min  .589
#  - night_call .523
#  - night_charge .815

# %%
df.columns
# Out:
# Index(['state', 'acct_len', 'area_code', 'intl_plan', 'vmail_plan',
#        'num_vmail_messages', 'day_min', 'day_calls', 'day_charge', 'eve_min',
#        'eve_calls', 'eve_charge', 'night_min', 'night_calls', 'night_charge',
#        'intl_min', 'intl_calls', 'intl_charge', 'cs_calls', 'target'],
#       dtype='object')

# %% [markdown]
# # 9. Multicolinearity #

# %%
def heatmap(df):
    corr = df.corr()
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    fig, ax = plt.subplots(figsize = (20, 20))
    sns.heatmap(corr, annot=True, cmap='coolwarm', mask=mask, ax=ax)
heatmap(df)

# %% [markdown]
# #### Correlation looks like we need to drop:
#    - intl_chg or intl_min(.93)
#    - night_chg or nit_min(.99)
#    - eve_chg or eve_min (1.0)
#    - day_chg or day_min (1.0)
# #### Little to no correlation for numerical data

# %%
df.drop('day_min', axis=1, inplace=True)
df.drop('eve_min', axis=1, inplace=True)
df.drop('night_min', axis=1, inplace=True)
df.drop('intl_min', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               3333 non-null   object
#  1   acct_len            3333 non-null   int64
#  2   area_code           3333 non-null   int64
#  3   intl_plan           3333 non-null   object
#  4   vmail_plan          3333 non-null   object
#  5   num_vmail_messages  3333 non-null   int64
#  6   day_calls           3333 non-null   int64
#  7   day_charge          3333 non-null   int64
#  8   eve_calls           3333 non-null   int64
#  9   eve_charge          3333 non-null   int64
#  10  night_calls         3333 non-null   int64
#  11  night_charge        3333 non-null   int64
#  12  intl_calls          3333 non-null   int64
#  13  intl_charge         3333 non-null   int64
#  14  cs_calls            3333 non-null   int64
#  15  target              3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#           acct_len    area_code  num_vmail_messages    day_calls   day_charge  \
# count  3333.000000  3333.000000         3333.000000  3333.000000  3333.000000
# mean    101.064806   437.182418            8.099010   100.435644    30.068407
# std      39.822106    42.371290           13.688365    20.069084     9.261643
# min       1.000000   408.000000            0.000000     0.000000     0.000000
# 25%      74.000000   408.000000            0.000000    87.000000    24.000000
# 50%     101.000000   415.000000            0.000000   101.000000    30.000000
# 75%     127.000000   510.000000           20.000000   114.000000    36.000000
# max     243.000000   510.000000           51.000000   165.000000    59.000000
#
#          eve_calls   eve_charge  night_calls  night_charge   intl_calls  \
# count  3333.000000  3333.000000  3333.000000   3333.000000  3333.000000
# mean    100.114311    16.585359   100.107711      8.541554     4.479448
# ...

# %%
heatmap(df)

# %% [markdown]
# Better without correlated items

# %%
pd.set_option("display.max_rows", 300)
pd.options.display.max_rows
corr = df.corr()
df_corr=corr.abs().stack().reset_index().sort_values(0, ascending=False)
print(df_corr[df_corr[0] > .75])
# Out:
#                 level_0             level_1    0
# 0              acct_len            acct_len  1.0
# 14            area_code           area_code  1.0
# 154            cs_calls            cs_calls  1.0
# 140         intl_charge         intl_charge  1.0
# 126          intl_calls          intl_calls  1.0
# 112        night_charge        night_charge  1.0
# 98          night_calls         night_calls  1.0
# 70            eve_calls           eve_calls  1.0
# 56           day_charge          day_charge  1.0
# 42            day_calls           day_calls  1.0
# 28   num_vmail_messages  num_vmail_messages  1.0
# 84           eve_charge          eve_charge  1.0
# 168              target              target  1.0

# %% [markdown]
# ## 10. Initial Feature Engineering

# %%
df_col = df.columns

# %% [markdown]
# ### Numeric Data

# %% [markdown]
# Add metrics to relate_cs calls to acct_len and to group call & charge into two columns.

# %%
df['calls_to_len'] = df['cs_calls'] / df['acct_len']
df['calls_to_len'].astype('float')
df['calls'] = df['day_calls'] + df['eve_calls'] + df['night_calls'] + df['intl_calls']
df['charge'] = df['day_charge'] + df['eve_charge'] + df['night_charge'] + df['intl_charge']
df['calls'].astype('int')
df['charge'].astype('int')
# Out:
# 0       74
# 1       57
# 2       61
# 3       64
# 4       50
#         ..
# 3328    58
# 3329    62
# 3330    65
# 3331    56
# 3332    74
# Name: charge, Length: 3333, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               3333 non-null   object
#  1   acct_len            3333 non-null   int64
#  2   area_code           3333 non-null   int64
#  3   intl_plan           3333 non-null   object
#  4   vmail_plan          3333 non-null   object
#  5   num_vmail_messages  3333 non-null   int64
#  6   day_calls           3333 non-null   int64
#  7   day_charge          3333 non-null   int64
#  8   eve_calls           3333 non-null   int64
#  9   eve_charge          3333 non-null   int64
#  10  night_calls         3333 non-null   int64
#  11  night_charge        3333 non-null   int64
#  12  intl_calls          3333 non-null   int64
#  13  intl_charge         3333 non-null   int64
#  14  cs_calls            3333 non-null   int64
#  15  target              3333 non-null   int64
# ...

# %%
num_cols = df.select_dtypes(include=np.number)
num_cols
# Out:
#       acct_len  area_code  num_vmail_messages  day_calls  day_charge  \
# 0          128        415                  25        110          45
# 1          107        415                  26        123          27
# 2          137        415                   0        114          41
# 3           84        408                   0         71          50
# 4           75        415                   0        113          28
# ...        ...        ...                 ...        ...         ...
# 3328       192        415                  36         77          26
# 3329        68        415                   0         57          39
# 3330        28        510                   0        109          30
# 3331       184        510                   0        105          36
# 3332        74        415                  25        113          39
#
#       eve_calls  eve_charge  night_calls  night_charge  intl_calls  \
# 0            99          16           91            11           3
# ...

# %%
heatmap(df)

# %% [markdown]
# Drop day charge due to colinearity with charge..

# %%
df.drop('day_charge', axis = 1, inplace=True)

# %%
heatmap(df)

# %%
mean_review = num_cols.groupby(df['target']).mean()
mean_review
# Out:
#           acct_len   area_code  num_vmail_messages   day_calls  day_charge  \
# target
# 0       100.793684  437.074737            8.604561  100.283158   29.284561
# 1       102.664596  437.817805            5.115942  101.335404   34.693582
#
#          eve_calls  eve_charge  night_calls  night_charge  intl_calls  \
# target
# 0       100.038596   16.420702   100.058246      8.512632    4.532982
# 1       100.561077   17.556936   100.399586      8.712215    4.163561
#
#         intl_charge  cs_calls  target  calls_to_len       calls     charge
# target
# 0          2.265614  1.449825     0.0      0.022142  304.912982  56.483509
# 1          2.387164  2.229814     1.0      0.038602  306.459627  63.349896

# %% [markdown]
# ### Categorical Data

# %% [markdown]
# Change area code to categorical as there are 3 area codes.

# %%
df['area_code']
# Out:
# 0       415
# 1       415
# 2       415
# 3       408
# 4       415
#        ...
# 3328    415
# 3329    415
# 3330    510
# 3331    510
# 3332    415
# Name: area_code, Length: 3333, dtype: int64

# %%
df['cat_area_code'] = '' 
for i, j in enumerate(df['area_code']):
    if j == 415:
       df['cat_area_code'].iloc[i] = 'SF'
    elif j == 408:
        df['cat_area_code'].iloc[i] = 'SJ'
    else:
        df['cat_area_code'].iloc[i] = 'AL'

# %%
cat_cols = df.select_dtypes(include=['O'])
cat_cols
# Out:
#      state intl_plan vmail_plan cat_area_code
# 0       KS        no        yes            SF
# 1       OH        no        yes            SF
# 2       NJ        no         no            SF
# 3       OH       yes         no            SJ
# 4       OK       yes         no            SF
# ...    ...       ...        ...           ...
# 3328    AZ        no        yes            SF
# 3329    WV        no         no            SF
# 3330    RI        no         no            AL
# 3331    CT       yes         no            AL
# 3332    TN        no        yes            SF
#
# [3333 rows x 4 columns]

# %% [markdown]
# Change state to Region - note: this code is turned off because statsmodel showed pvalues of 1.

# %%
# state_code = pd.read_csv('state.csv')
# state_code.head()
# state_code_dict = dict(zip(state_code['State Code'], state_code['Region']))
# state_code_dict

# %%
# df['region'] = df['state'].map(state_code_dict)
# df['region'].astype('O')
# df['region'].value_counts(dropna = False)
# df.head()

# %%
cat_cols = df.select_dtypes(include=['O'])
cat_cols
# Out:
#      state intl_plan vmail_plan cat_area_code
# 0       KS        no        yes            SF
# 1       OH        no        yes            SF
# 2       NJ        no         no            SF
# 3       OH       yes         no            SJ
# 4       OK       yes         no            SF
# ...    ...       ...        ...           ...
# 3328    AZ        no        yes            SF
# 3329    WV        no         no            SF
# 3330    RI        no         no            AL
# 3331    CT       yes         no            AL
# 3332    TN        no        yes            SF
#
# [3333 rows x 4 columns]

# %%
df.drop('state', axis=1, inplace=True)

# %%
df['target'].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: target, dtype: float64

# %% [markdown]
# #### Target-mean analysis

# %%
df.groupby(df['target']).mean()
# Out:
#           acct_len   area_code  num_vmail_messages   day_calls   eve_calls  \
# target
# 0       100.793684  437.074737            8.604561  100.283158  100.038596
# 1       102.664596  437.817805            5.115942  101.335404  100.561077
#
#         eve_charge  night_calls  night_charge  intl_calls  intl_charge  \
# target
# 0        16.420702   100.058246      8.512632    4.532982     2.265614
# 1        17.556936   100.399586      8.712215    4.163561     2.387164
#
#         cs_calls  calls_to_len       calls     charge
# target
# 0       1.449825      0.022142  304.912982  56.483509
# 1       2.229814      0.038602  306.459627  63.349896

# %% [markdown]
#  1. Slightly more churn for customers with longer
#     acc_len.
#  2. More num_vmail_messages for longer term customers
#  3.Charge significantly higher for customers who 'churn'.
#  4.  Calls are somewhat higher for churn customers and calls_to_len only almost 2 times higher

# %%
y = df['target']
df.drop('target', axis=1, inplace=True)
X = df.copy()

# %% [markdown]
# ## Preprocessing

# %%
#%conda list scikit-learn

# %%
#%conda update scikit-learn

# %%
#!pip install -U matplotlib

# %%
#!pip install -U fsds

# %%
#conda install -c conda-forge imbalanced-learn

# %%
#from fsds.imports import *
import statsmodels.api as sm

# %% [markdown]
# ### Train , test, split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.35, random_state = 100)
X_train.shape, y_train.shape, y_test.shape, y_test.shape
# Out:
# ((2166, 17), (2166,), (1167,), (1167,))

# %%
cat_cols = X_train.select_dtypes('O').columns
cat_cols
# Out:
# Index(['intl_plan', 'vmail_plan', 'cat_area_code'], dtype='object')

# %%
X_train.isna().sum()
# Out:
# acct_len              0
# area_code             0
# intl_plan             0
# vmail_plan            0
# num_vmail_messages    0
# day_calls             0
# eve_calls             0
# eve_charge            0
# night_calls           0
# night_charge          0
# intl_calls            0
# intl_charge           0
# cs_calls              0
# calls_to_len          0
# calls                 0
# charge                0
# cat_area_code         0
# dtype: int64

# %% [markdown]
# ### One Hot Encoding

# %%
encoder = OneHotEncoder(sparse=False,drop='if_binary')
encoder
# Out:
# OneHotEncoder(drop='if_binary', sparse=False)

# %%
#OHE numeric train/test data
X_train_ohe = X_train.drop(columns=cat_cols).copy()
X_test_ohe = X_test.drop(columns=cat_cols).copy()


encoder.fit(X_train[cat_cols])

X_train_ohe[encoder.get_feature_names(cat_cols)] = encoder.transform(X_train[cat_cols])
X_test_ohe[encoder.get_feature_names(cat_cols)] = encoder.transform(X_test[cat_cols])

# %%
X_train_ohe.head()
# Out:
#       acct_len  area_code  num_vmail_messages  day_calls  eve_calls  \
# 3009       133        408                  39        107         77
# 3217       164        510                  30        100        121
# 1052        98        415                   0         67         90
# 1949        73        415                   0        109         83
# 3116       149        408                   0         83         81
#
#       eve_charge  night_calls  night_charge  intl_calls  intl_charge  \
# 3009          21           85             5           3            1
# 3217          19           66             9           8            3
# 1052          21           88             7           9            2
# 1949          22           91             8           8            2
# 3116          17           79            11           1            2
#
#       cs_calls  calls_to_len  calls  charge  intl_plan_yes  vmail_plan_yes  \
# ...

# %%
X_train_ohe.describe().round(2)
# Out:
#        acct_len  area_code  num_vmail_messages  day_calls  eve_calls  \
# count   2166.00    2166.00             2166.00    2166.00    2166.00
# mean     101.17     437.16                7.86     100.33     100.38
# std       40.04      42.45               13.51      20.33      20.20
# min        1.00     408.00                0.00       0.00       0.00
# 25%       74.00     408.00                0.00      87.00      87.00
# 50%      101.00     415.00                0.00     101.00     101.00
# 75%      128.00     510.00               19.00     114.00     114.00
# max      243.00     510.00               48.00     165.00     170.00
#
#        eve_charge  night_calls  night_charge  intl_calls  intl_charge  \
# count     2166.00      2166.00       2166.00     2166.00       2166.0
# mean        16.61        99.69          8.52        4.44          2.3
# std          4.28        19.64          2.26        2.48          0.8
# ...

# %%
X_train_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2166 entries, 3009 to 1544
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   acct_len            2166 non-null   int64
#  1   area_code           2166 non-null   int64
#  2   num_vmail_messages  2166 non-null   int64
#  3   day_calls           2166 non-null   int64
#  4   eve_calls           2166 non-null   int64
#  5   eve_charge          2166 non-null   int64
#  6   night_calls         2166 non-null   int64
#  7   night_charge        2166 non-null   int64
#  8   intl_calls          2166 non-null   int64
#  9   intl_charge         2166 non-null   int64
#  10  cs_calls            2166 non-null   int64
#  11  calls_to_len        2166 non-null   float64
#  12  calls               2166 non-null   int64
#  13  charge              2166 non-null   int64
#  14  intl_plan_yes       2166 non-null   float64
# ...

# %% [markdown]
# ### Label Binarizer

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(y_train)
lb.classes_
y_train_lb = lb.transform(y_train)
y_train_lb
y_test_lb = lb.transform(y_test)

# %% [markdown]
# from sklearn import preprocessing
# lb = preprocessing.LabelBinarizer()
# lb.fit(y_test)
# lb.classes_
# y_test_lb = lb.transform(y_test)
# y_test_lb

# %% [markdown]
# ### Scale data

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler= StandardScaler()

X_train_scale = X_train_ohe.copy()
X_test_scale = X_test_ohe.copy()
y_train_scale = y_train_lb.copy()
y_test_scale = y_test_lb.copy()

X_train_scale = scaler.fit_transform(X_train_scale)
X_test_scale = scaler.transform(X_test_scale)

y_train_scale= np.array(y_train_lb)
y_test_scale = np.array(y_test_lb)

# %%
X_train_scale_df = pd.DataFrame(X_train_scale, X_train_ohe.index, X_train_ohe.columns)
X_test_scale_df = pd.DataFrame(X_test_scale, X_test_ohe.index, X_test_ohe.columns)
X_train_scale_df
# Out:
#       acct_len  area_code  num_vmail_messages  day_calls  eve_calls  \
# 3009  0.794929  -0.686985            2.305499   0.328260  -1.157338
# 3217  1.569251   1.716413            1.639227  -0.016198   1.020933
# 1052 -0.079305  -0.522046           -0.581681  -1.640073  -0.513758
# 1949 -0.703758  -0.522046           -0.581681   0.426677  -0.860301
# 3116  1.194579  -0.686985           -0.581681  -0.852740  -0.959313
# ...        ...        ...                 ...        ...        ...
# 1930  1.019732  -0.522046           -0.581681  -0.360657  -0.117709
# 79   -0.778692  -0.686985           -0.581681  -0.114615   0.080316
# 1859  0.370301   1.716413           -0.581681   0.475885   0.129822
# 2840  0.170476  -0.522046            2.453560   0.475885  -1.107832
# 1544  0.969776  -0.686985           -0.581681  -0.114615   0.426859
#
#       eve_charge  night_calls  night_charge  intl_calls  intl_charge  \
# 3009    1.026648    -0.748241     -1.554997   -0.580219    -1.613156
# ...

# %% [markdown]
# ## Logistic Regression - Model 1.v1 & v2- statsmodel

# %% [markdown]
# ### v1. All features, no balance
# ### v2. All features except region/state, no balance

# %%
import statsmodels.api as sms

# %% [markdown]
# After 1st round, high pvalues to be deleted:
#     acct_len, area_code, cs_calls, calls_to_len

# %%
X_train_scale_df
# Out:
#       acct_len  area_code  num_vmail_messages  day_calls  eve_calls  \
# 3009  0.794929  -0.686985            2.305499   0.328260  -1.157338
# 3217  1.569251   1.716413            1.639227  -0.016198   1.020933
# 1052 -0.079305  -0.522046           -0.581681  -1.640073  -0.513758
# 1949 -0.703758  -0.522046           -0.581681   0.426677  -0.860301
# 3116  1.194579  -0.686985           -0.581681  -0.852740  -0.959313
# ...        ...        ...                 ...        ...        ...
# 1930  1.019732  -0.522046           -0.581681  -0.360657  -0.117709
# 79   -0.778692  -0.686985           -0.581681  -0.114615   0.080316
# 1859  0.370301   1.716413           -0.581681   0.475885   0.129822
# 2840  0.170476  -0.522046            2.453560   0.475885  -1.107832
# 1544  0.969776  -0.686985           -0.581681  -0.114615   0.426859
#
#       eve_charge  night_calls  night_charge  intl_calls  intl_charge  \
# 3009    1.026648    -0.748241     -1.554997   -0.580219    -1.613156
# ...

# %%
X_train_sms_df = sm.add_constant(X_train_scale_df)
X_test_sms_df = sm.add_constant(X_test_scale_df)

# %%
X_train_sms = np.array(X_train_sms_df)
X_test_sms = np.array(X_test_sms_df)

# %%
results = sm.Logit(y_train_lb,X_train_sms_df).fit(maxiter=100 )
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.337752
#          Iterations 39
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                 2166
# Model:                          Logit   Df Residuals:                     2149
# Method:                           MLE   Df Model:                           16
# Date:                Thu, 15 Oct 2020   Pseudo R-squ.:                  0.2086
# Time:                        20:20:05   Log-Likelihood:                -731.57
# converged:                       True   LL-Null:                       -924.39
# Covariance Type:            nonrobust   LLR p-value:                 3.720e-72
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Drop regions - original run had 13 features.  the 4 regions had pvalues of 1.0 so we turned off the creation of the regions above and dropped 'state'

# %% [markdown]
# The log likelihood at such a high negative number does not produce any confidence in the underlying data.  The pseudo-R2 is low and the p-values are very high and would exclude most of the data......try balancing and a different model.

# %% [markdown]
# With p-values > 5, we should drop acct_len, area_code, #vm_messages, day_calls, eve_calls, eve_charge, night_calls, night_charge, intl_calls, calls_to_len, calls, area_code_AL, area_code_SJ, area_code_SF, region_Midwest, region_Northeast, region_south, region_west

# %%
X_train_sms_df1 = pd.DataFrame()
X_train_sms_df1 = X_train_sms_df.copy()
X_train_sms_df1.drop(['acct_len'], axis=1, inplace=True)
X_train_sms_df1.drop(['area_code'], axis=1, inplace=True)
X_train_sms_df1.drop(['num_vmail_messages'], axis=1, inplace=True)
X_train_sms_df1.drop(['day_calls'], axis=1, inplace=True)
X_train_sms_df1.drop(['eve_calls'], axis=1, inplace=True)
X_train_sms_df1.drop(['eve_charge'], axis=1, inplace=True)
X_train_sms_df1.drop(['night_calls'], axis=1, inplace=True)
X_train_sms_df1.drop(['night_charge'], axis=1, inplace=True)
X_train_sms_df1.drop(['intl_calls'], axis=1, inplace=True)
X_train_sms_df1.drop(['calls_to_len'], axis=1, inplace=True)
X_train_sms_df1.drop(['calls'], axis=1, inplace=True)
X_train_sms_df1.drop(['cat_area_code_AL'], axis=1, inplace=True)
X_train_sms_df1.drop(['cat_area_code_SJ'], axis=1, inplace=True)
X_train_sms_df1.drop(['cat_area_code_SF'], axis=1, inplace=True)
X_train_sms_df1
# Out:
#       const  intl_charge  cs_calls    charge  intl_plan_yes  vmail_plan_yes
# 3009    1.0    -1.613156  2.590865  0.924353      -0.330247        1.647806
# 3217    1.0     0.877290 -0.445420  1.306825      -0.330247        1.647806
# 1052    1.0    -0.367933 -0.445420 -2.422282       3.028038       -0.606867
# 1949    1.0    -0.367933 -1.204491  0.063790      -0.330247       -0.606867
# 3116    1.0    -0.367933 -0.445420  0.350644      -0.330247       -0.606867
# ...     ...          ...       ...       ...            ...             ...
# 1930    1.0    -0.367933 -0.445420 -0.509919      -0.330247       -0.606867
# 79      1.0     2.122514 -0.445420 -0.223065      -0.330247       -0.606867
# 1859    1.0    -0.367933 -1.204491  0.446262      -0.330247       -0.606867
# 2840    1.0    -0.367933 -1.204491 -0.701156      -0.330247        1.647806
# 1544    1.0    -0.367933 -0.445420 -0.509919      -0.330247       -0.606867
#
# [2166 rows x 6 columns]

# %%
X_train_sms_df1
# Out:
#       const  intl_charge  cs_calls    charge  intl_plan_yes  vmail_plan_yes
# 3009    1.0    -1.613156  2.590865  0.924353      -0.330247        1.647806
# 3217    1.0     0.877290 -0.445420  1.306825      -0.330247        1.647806
# 1052    1.0    -0.367933 -0.445420 -2.422282       3.028038       -0.606867
# 1949    1.0    -0.367933 -1.204491  0.063790      -0.330247       -0.606867
# 3116    1.0    -0.367933 -0.445420  0.350644      -0.330247       -0.606867
# ...     ...          ...       ...       ...            ...             ...
# 1930    1.0    -0.367933 -0.445420 -0.509919      -0.330247       -0.606867
# 79      1.0     2.122514 -0.445420 -0.223065      -0.330247       -0.606867
# 1859    1.0    -0.367933 -1.204491  0.446262      -0.330247       -0.606867
# 2840    1.0    -0.367933 -1.204491 -0.701156      -0.330247        1.647806
# 1544    1.0    -0.367933 -0.445420 -0.509919      -0.330247       -0.606867
#
# [2166 rows x 6 columns]

# %%
X_test_sms_df1 = pd.DataFrame()
X_test_sms_df1 = X_test_sms_df.copy()
X_test_sms_df1.drop(['acct_len'], axis=1, inplace=True)
X_test_sms_df1.drop(['area_code'], axis=1, inplace=True)
X_test_sms_df1.drop(['num_vmail_messages'], axis=1, inplace=True)
X_test_sms_df1.drop(['day_calls'], axis=1, inplace=True)
X_test_sms_df1.drop(['eve_calls'], axis=1, inplace=True)
X_test_sms_df1.drop(['eve_charge'], axis=1, inplace=True)
X_test_sms_df1.drop(['night_calls'], axis=1, inplace=True)
X_test_sms_df1.drop(['night_charge'], axis=1, inplace=True)
X_test_sms_df1.drop(['intl_calls'], axis=1, inplace=True)
X_test_sms_df1.drop(['calls_to_len'], axis=1, inplace=True)
X_test_sms_df1.drop(['calls'], axis=1, inplace=True)
X_test_sms_df1.drop(['cat_area_code_AL'], axis=1, inplace=True)
X_test_sms_df1.drop(['cat_area_code_SJ'], axis=1, inplace=True)
X_test_sms_df1.drop(['cat_area_code_SF'], axis=1, inplace=True)
X_test_sms_df1
# Out:
#       const  intl_charge  cs_calls    charge  intl_plan_yes  vmail_plan_yes
# 1997    1.0     0.877290  1.072723  0.828735      -0.330247       -0.606867
# 1736    1.0    -1.613156 -0.445420  1.593680      -0.330247       -0.606867
# 962     1.0    -0.367933  1.072723  0.159408      -0.330247       -0.606867
# 263     1.0     0.877290 -0.445420  0.159408      -0.330247       -0.606867
# 1436    1.0    -0.367933 -0.445420  0.733117      -0.330247        1.647806
# ...     ...          ...       ...       ...            ...             ...
# 1614    1.0     0.877290 -0.445420  1.689298      -0.330247       -0.606867
# 498     1.0    -0.367933  1.831794 -0.509919       3.028038       -0.606867
# 2222    1.0     0.877290 -1.204491 -0.031829      -0.330247        1.647806
# 3154    1.0    -1.613156  0.313651 -0.318683      -0.330247        1.647806
# 114     1.0    -0.367933 -0.445420 -2.135428      -0.330247       -0.606867
#
# [1167 rows x 6 columns]

# %% [markdown]
# ## Logistic Regression - Model 1.v3 - statsmodel

# %% [markdown]
# ### Drop all but 5 features

# %%
X_train_sms1 = X_train_sms_df1.to_numpy()
X_test_sms1 = X_test_sms_df1.to_numpy()

print(X_train_sms_df1.shape, y_train_lb.shape, X_test_sms_df1.shape, y_test_lb.shape)
print(X_train_sms1)
# Out:
# (2166, 6) (2166, 1) (1167, 6) (1167, 1)
# [[ 1.         -1.61315633  2.59086499  0.92435281 -0.33024685  1.64780638]
#  [ 1.          0.87729029 -0.44541991  1.30682536 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -2.422282    3.02803799 -0.60686742]
#  ...
#  [ 1.         -0.36793302 -1.20449114  0.44626212 -0.33024685 -0.60686742]
#  [ 1.         -0.36793302 -1.20449114 -0.70115553 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -0.50991925 -0.33024685 -0.60686742]]

# %%
print(X_test_sms1)
# Out:
# [[ 1.          0.87729029  1.07272254  0.82873467 -0.33024685 -0.60686742]
#  [ 1.         -1.61315633 -0.44541991  1.59367977 -0.33024685 -0.60686742]
#  [ 1.         -0.36793302  1.07272254  0.15940771 -0.33024685 -0.60686742]
#  ...
#  [ 1.          0.87729029 -1.20449114 -0.03182857 -0.33024685  1.64780638]
#  [ 1.         -1.61315633  0.31365131 -0.31868298 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -2.13542759 -0.33024685 -0.60686742]]

# %%
results = sm.Logit(y_train_lb,X_train_sms_df1).fit(maxiter=100 )
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.339943
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                 2166
# Model:                          Logit   Df Residuals:                     2160
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 15 Oct 2020   Pseudo R-squ.:                  0.2035
# Time:                        20:20:05   Log-Likelihood:                -736.32
# converged:                       True   LL-Null:                       -924.39
# Covariance Type:            nonrobust   LLR p-value:                 4.099e-79
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# note: turned off the code above which creates the regions.

# %% [markdown]
# Metrics worse....let's move to new model

# %% [markdown]
# ## Logistic Regression - Model 2.v1 - sklearn

# %% [markdown]
# ### All features, no balance

# %%
import sklearn.preprocessing, sklearn.decomposition, \
...     sklearn.linear_model, sklearn.pipeline, sklearn.metrics

from sklearn import metrics
from sklearn.metrics import confusion_matrix as cnf
from sklearn.linear_model import LogisticRegressionCV

# %%
y_train_lb
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
print(X_train_sms_df.shape, X_test_sms_df.shape, y_train_lb.shape, y_test_lb.shape)
# Out:
# (2166, 20) (1167, 20) (2166, 1) (1167, 1)

# %%
def sklearn_log_reg(X_train, X_test, y_train, y_test):    
    fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 8))
    logreg = LogisticRegressionCV(fit_intercept=False)
    logreg.fit(X_train, y_train)
    y_pred=logreg.predict(X_test)
    y_pred
    
    

    classes = ['Churn', 'NoChurn']
    print('Metrics - Classification Report\n')
    print(metrics.classification_report(y_test, y_pred, target_names=['Churn','No Churn'])) 
    plt.show()

    cm = metrics.confusion_matrix(y_test, y_pred,normalize='true') 
    ax = sns.heatmap(cm, annot=True, center =0 , 
    xticklabels=classes,yticklabels=classes,cmap='Blues')
    ax.set(ylabel='True Classs',xlabel='Predicted Class', 
    title='Normalized Confusion Matrix')

    
    print('\n\n\n X_train_sms\n\n')
    print(X_train)

# %%
print(X_train_sms.shape, X_test_sms.shape, y_train_lb.shape, y_test_lb.shape)
# Out:
# (2166, 20) (1167, 20) (2166, 1) (1167, 1)

# %%
sklearn_log_reg(X_train_sms, X_test_sms, y_train_lb, y_test_lb)
# Out:
# Metrics - Classification Report
#
#               precision    recall  f1-score   support
#
#        Churn       0.89      0.98      0.93      1014
#     No Churn       0.59      0.19      0.29       153
#
#     accuracy                           0.88      1167
#    macro avg       0.74      0.58      0.61      1167
# weighted avg       0.85      0.88      0.85      1167
#  X_train_sms
#
#
# [[ 1.          0.79492919 -0.68698508 ... -0.58125973 -0.97087636
#    1.67731341]
#  [ 1.          1.56925085  1.71641292 ...  1.7204013  -0.97087636
#   -0.5961915 ]
#  [ 1.         -0.07930495 -0.522046   ... -0.58125973  1.02999727
#   -0.5961915 ]
#  ...
#  [ 1.          0.37030118  1.71641292 ...  1.7204013  -0.97087636
#   -0.5961915 ]
#  [ 1.          0.17047623 -0.522046   ... -0.58125973  1.02999727
#   -0.5961915 ]
#  [ 1.          0.96977601 -0.68698508 ... -0.58125973 -0.97087636
#    1.67731341]]

# %% [markdown]
# Overfitting?
# Confusion matrix shows that the sample is unbalanced as the actual balance is 85% No Churn and 15% Churn

# %%
#from sklearn.linear_model import LogisticRegressionCV
logreg = LogisticRegressionCV(fit_intercept=False)
logreg.fit(X_train_sms, y_train_lb)

def metrics(X_test, y_test):
    from sklearn import metrics
    y_pred_proba = logreg.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
    plt.legend(loc=4)
    plt.plot([0,1],[0,1],'r--')
    plt.show()

metrics(X_test_sms, y_test_lb)

# %% [markdown]
# Lower ROC/AUC probably due to imbalance.

# %%
pd.DataFrame(logreg.coef_[0], X_train_sms_df.columns, columns=['Coeff'])
# Out:
#                        Coeff
# const              -1.205032
# acct_len            0.018975
# area_code          -0.007001
# num_vmail_messages -0.064240
# day_calls           0.030963
# eve_calls           0.003640
# eve_charge          0.028156
# night_calls         0.007175
# night_charge        0.017586
# intl_calls         -0.058749
# intl_charge         0.064909
# cs_calls            0.308483
# calls_to_len        0.051408
# calls               0.020137
# charge              0.304485
# intl_plan_yes       0.323732
# vmail_plan_yes     -0.100013
# cat_area_code_AL   -0.005980
# cat_area_code_SF   -0.009180
# cat_area_code_SJ    0.016338

# %% [markdown]
# Interestingly, the intl_plan_yes(.323) and charge(.304) sum to .627 of the contribution to explaining the model.

# %% [markdown]
# ### Logistic Regression - Model 2 - sklearn v2

# %% [markdown]
# Change weight to balanced, ds after scale

# %%
def sklearn_log_reg1(X_train, X_test, y_train, y_test):
    from sklearn.metrics import classification_report
    from sklearn import metrics
    logreg = LogisticRegressionCV(class_weight='balanced', fit_intercept=False)
    logreg.fit(X_train, y_train)
    y_pred=logreg.predict(X_test)
    y_pred
    

    classes = ['Churn', 'NoChurn']
    print('Metrics - Classification Report\n')
    print(metrics.classification_report(y_test, y_pred, target_names=classes)) 

#    print(metrics.classification_report(y_test, y_pred, labels=None, target_names=classes, sample_weight=None, digits=2, output_dict=False, zero_division='warn'))

    cm = metrics.confusion_matrix(y_test, y_pred, normalize='true') 
    ax = sns.heatmap(cm, annot=True, center =0 , 
    xticklabels=classes,yticklabels=classes,cmap='Blues')
    ax.set(ylabel='True Classs',xlabel='Predicted Class', 
    title='Normalized Confusion Matrix')

    
    print('\n\n\n X_train_sms\n\n')
    print(X_train)

# %%
print(X_train_sms.shape, X_test_sms.shape, y_train.shape, y_test.shape) ## array
# Out:
# (2166, 20) (1167, 20) (2166,) (1167,)

# %%
print(X_train_sms)
# Out:
# [[ 1.          0.79492919 -0.68698508 ... -0.58125973 -0.97087636
#    1.67731341]
#  [ 1.          1.56925085  1.71641292 ...  1.7204013  -0.97087636
#   -0.5961915 ]
#  [ 1.         -0.07930495 -0.522046   ... -0.58125973  1.02999727
#   -0.5961915 ]
#  ...
#  [ 1.          0.37030118  1.71641292 ...  1.7204013  -0.97087636
#   -0.5961915 ]
#  [ 1.          0.17047623 -0.522046   ... -0.58125973  1.02999727
#   -0.5961915 ]
#  [ 1.          0.96977601 -0.68698508 ... -0.58125973 -0.97087636
#    1.67731341]]

# %%
sklearn_log_reg1(X_train_sms1, X_test_sms1, y_train_lb, y_test_lb)
# Out:
# Metrics - Classification Report
#
#               precision    recall  f1-score   support
#
#        Churn       0.95      0.78      0.85      1014
#      NoChurn       0.33      0.73      0.45       153
#
#     accuracy                           0.77      1167
#    macro avg       0.64      0.75      0.65      1167
# weighted avg       0.87      0.77      0.80      1167
#
#
#
#
#  X_train_sms
#
#
# [[ 1.         -1.61315633  2.59086499  0.92435281 -0.33024685  1.64780638]
#  [ 1.          0.87729029 -0.44541991  1.30682536 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -2.422282    3.02803799 -0.60686742]
#  ...
#  [ 1.         -0.36793302 -1.20449114  0.44626212 -0.33024685 -0.60686742]
#  [ 1.         -0.36793302 -1.20449114 -0.70115553 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -0.50991925 -0.33024685 -0.60686742]]

# %%
print(logreg.coef_)
# Out:
# [[-1.20503222  0.01897549 -0.00700142 -0.06423988  0.03096345  0.00363961
#    0.0281561   0.00717481  0.01758604 -0.05874937  0.06490937  0.30848258
#    0.05140788  0.02013664  0.30448545  0.32373239 -0.10001322 -0.00598037
#   -0.00917971  0.01633771]]

# %%
pd.DataFrame(logreg.coef_[0], X_train_sms_df.columns, columns=['Coeff'])
# Out:
#                        Coeff
# const              -1.205032
# acct_len            0.018975
# area_code          -0.007001
# num_vmail_messages -0.064240
# day_calls           0.030963
# eve_calls           0.003640
# eve_charge          0.028156
# night_calls         0.007175
# night_charge        0.017586
# intl_calls         -0.058749
# intl_charge         0.064909
# cs_calls            0.308483
# calls_to_len        0.051408
# calls               0.020137
# charge              0.304485
# intl_plan_yes       0.323732
# vmail_plan_yes     -0.100013
# cat_area_code_AL   -0.005980
# cat_area_code_SF   -0.009180
# cat_area_code_SJ    0.016338

# %%
from sklearn.linear_model import LogisticRegressionCV
logreg = LogisticRegressionCV()
logreg.fit(X_train_sms, y_train_lb)

from sklearn import metrics
y_pred_proba = logreg.predict_proba(X_test_sms)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test_lb,  y_pred_proba)
auc = metrics.roc_auc_score(y_test_lb, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.plot([0,1],[0,1],'r--')
plt.show()

# %% [markdown]
# ### Logistic Regression - Model 2 - sklearnv3

# %% [markdown]
# ### Balanced, 5 features

# %%
print(X_train_sms_df1.shape, X_test_sms_df1.shape, y_train_lb.shape, y_test_lb.shape)
# Out:
# (2166, 6) (1167, 6) (2166, 1) (1167, 1)

# %%
print(X_train_sms1)
# Out:
# [[ 1.         -1.61315633  2.59086499  0.92435281 -0.33024685  1.64780638]
#  [ 1.          0.87729029 -0.44541991  1.30682536 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -2.422282    3.02803799 -0.60686742]
#  ...
#  [ 1.         -0.36793302 -1.20449114  0.44626212 -0.33024685 -0.60686742]
#  [ 1.         -0.36793302 -1.20449114 -0.70115553 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -0.50991925 -0.33024685 -0.60686742]]

# %%
sklearn_log_reg1(X_train_sms1, X_test_sms1, y_train_lb, y_test_lb)
# Out:
# Metrics - Classification Report
#
#               precision    recall  f1-score   support
#
#        Churn       0.95      0.78      0.85      1014
#      NoChurn       0.33      0.73      0.45       153
#
#     accuracy                           0.77      1167
#    macro avg       0.64      0.75      0.65      1167
# weighted avg       0.87      0.77      0.80      1167
#
#
#
#
#  X_train_sms
#
#
# [[ 1.         -1.61315633  2.59086499  0.92435281 -0.33024685  1.64780638]
#  [ 1.          0.87729029 -0.44541991  1.30682536 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -2.422282    3.02803799 -0.60686742]
#  ...
#  [ 1.         -0.36793302 -1.20449114  0.44626212 -0.33024685 -0.60686742]
#  [ 1.         -0.36793302 -1.20449114 -0.70115553 -0.33024685  1.64780638]
#  [ 1.         -0.36793302 -0.44541991 -0.50991925 -0.33024685 -0.60686742]]

# %%
print(logreg.coef_[0])
# Out:
# [-3.08341250e-05  2.76651958e-02 -1.42888051e-02 -7.64054260e-02
#   5.85813372e-02  4.54463970e-03  6.48694361e-03  1.61636146e-02
#   1.97800926e-02 -1.30267837e-01  1.29400796e-01  6.20478888e-01
#   6.24814675e-02  3.68323964e-02  6.84946819e-01  5.60250111e-01
#  -2.59148107e-01 -1.21559898e-02 -1.93550098e-02  3.39995345e-02]

# %%
X_train_sms_df1.head()
# Out:
#       const  intl_charge  cs_calls    charge  intl_plan_yes  vmail_plan_yes
# 3009    1.0    -1.613156  2.590865  0.924353      -0.330247        1.647806
# 3217    1.0     0.877290 -0.445420  1.306825      -0.330247        1.647806
# 1052    1.0    -0.367933 -0.445420 -2.422282       3.028038       -0.606867
# 1949    1.0    -0.367933 -1.204491  0.063790      -0.330247       -0.606867
# 3116    1.0    -0.367933 -0.445420  0.350644      -0.330247       -0.606867

# %%
pd.DataFrame(logreg.coef_, X_train_sms_df1.columns, columns=['Coeff'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1661                 blocks = [
# -> 1662                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1663                 ]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2718
# -> 2719     return klass(values, ndim=ndim, placement=placement)
#    2720
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     129             raise ValueError(
# --> 130                 f"Wrong number of items passed {len(self.values)}, "
# ...

# %%
from sklearn import metrics
y_pred_proba = logreg.predict_proba(X_test_sms_df1)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test_lb,  y_pred_proba)
auc = metrics.roc_auc_score(y_test_lb, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.plot([0,1],[0,1],'r--')
plt.show()

# %%
plt.hist(y_test - y_pred_proba)

# %% [markdown]
# ### Gridsearch

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, precision_recall_curve, auc, roc_auc_score, roc_curve, recall_score, classification_report

parameters = {
    'C': np.linspace(1, 10, 10)
             }
lr = LogisticRegression()
clf = GridSearchCV(lr, parameters, cv=5, verbose=5, n_jobs=None)
clf.fit(X_train_sms_df, y_train_lb.ravel())

# %%
clf.best_params_

# %%
print(X_train_sms_df1.shape, X_test_sms_df1.shape, y_train_lb.shape, y_test_lb.shape)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=100, random_state = 40)

# %%
clf.fit(X_train_sms,y_train_lb)

y_pred=clf.predict(X_test_sms)
y_pred

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test_lb, y_pred))

# %%
feature_imp = pd.Series(clf.feature_importances_,index=X_test_sms_df.columns).sort_values(ascending=False)
feature_imp

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test_lb,y_pred))
print(classification_report(y_test_lb,y_pred))
print(accuracy_score(y_test_lb, y_pred))

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
rfc = RandomForestClassifier(random_state=2020)

# %%
knn = KNeighborsClassifier()

# %%
lr = LogisticRegression(penalty='none', random_state=2020)

# %%
estimators = [
    ("random_forest", rfc),
    ("knn", knn),
    ("logistic_regression", lr)
]

# %%
stack = StackingClassifier(estimators=estimators)

# %%
# %time
stack.fit(X_train_sms, y_train_lb)

# %%
StackingClassifier(cv=None,
                   estimators=[('random_forest',
                                RandomForestClassifier(bootstrap=True,
                                                       ccp_alpha=0.0,
                                                       class_weight=None,
                                                       criterion='gini',
                                                       max_depth=None,
                                                       max_features='auto',
                                                       max_leaf_nodes=None,
                                                       max_samples=None,
                                                       min_impurity_decrease=0.0,
                                                       min_impurity_split=None,
                                                       min_samples_leaf=1,
                                                       min_samples_split=2,
                                                       min_weight_fraction_leaf=0.0,
                                                       n_estimators=100,
                                                       )),
                               ('linear_regression',
                                LogisticRegression(C=1.0, class_weight=None,
                                                   dual=False,
                                                   fit_intercept=True,
                                                   intercept_scaling=1,
                                                   l1_ratio=None, max_iter=100,
                                                   multi_class='auto',
                                                   n_jobs=None, penalty='none',
                                                   random_state=2020,
                                                   solver='lbfgs', tol=0.0001,
                                                   verbose=0,
                                                   warm_start=False))],
                   final_estimator=None, n_jobs=None, passthrough=False,
                   stack_method='auto', verbose=0)

# %%
stack.score(X_test_sms, y_test_lb)

# %%
rfc.fit(X_train_sms, y_train_lb)
rfc.score(X_test_sms, y_test_lb)

# %%
knn.fit(X_train_sms, y_train_lb)
knn.score(X_test_sms, y_test_lb)

# %%
lr.fit(X_train_sms, y_train_lb)
lr.score(X_test_sms, y_test_lb)

# %% [markdown]
# ## XG Boost

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
data_dmatrix = xgb.DMatrix(data=X_train_sms,label=y_train_lb)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(X_train_sms,y_train_lb)

preds = xg_reg.predict(X_test_sms)

# %%
rmse = np.sqrt(mean_squared_error(y_test_lb, preds))
print("RMSE: %f" % (rmse))

# %% [markdown]
# # 19. Cross - Validation

# %%
params = {"objective":'reg:squarederror','colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
cv_results

# %%
print((cv_results["test-rmse-mean"]).tail(1))

# %%
xg_reg = xgb.train(params=params, dtrain=data_dmatrix, num_boost_round=10)

# %%
#conda config --add channels conda-forge

# %%
#conda install python-graphviz
#conda search python-graphviz --channel conda-forge

# %%
xgb.plot_tree(xg_reg,num_trees=0)
plt.rcParams['figure.figsize'] = [50, 10]
plt.show()

# %% [markdown]
# # 20. Conclusion

# %% [markdown]
# ## The Data

# %% [markdown]
# ## Conclusion

# %%
df.to_csv('df_out.csv')
